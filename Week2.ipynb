# %% [markdown]
# <a href="https://colab.research.google.com/github/muzakidian/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nama : Akhmad Dian Muzaki
#Kelas: TI-3G
#Absen: 03
#NIM  : 1941720205

# %%
from google.colab import drive

#Accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#Simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.triff',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran 10x10 sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#MENAMBAH BENTUK PERSEGI

#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
#MENAMBAHKAN FONT
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#inisialisasi NumPy array dengan tpe data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
#Array tersebut kemudian di reshape sebagai berikut
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed = True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#TUGAS NO 1
#Tampilkan image dalam channel Red-Green dan Green-Blue saja!
#Red-Green
red_green = img.copy()
red_green[:,:,2] = 0
plt.imshow(red_green)

# %%
#Green-Blue
green_blue = img
green_blue[:,:,0] = 0
plt.imshow(green_blue)

# %%
#TUGAS NO 2
#Tampilkan image baris ke 10-100, kolom 10-100!
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
#TUGAS NO 3
#Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
plt.imshow(img[5:30])

# %%
#TUGAS NO 4
#Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
#disarankan menggunakan bilangan acak/random!

me = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/ME.jpg')
me = cv.cvtColor(me, cv.COLOR_BGR2RGB)
cv.rectangle(me, pt1=(300,300), pt2=(40,170), color=(0,255,255),thickness=10)
cv.rectangle(me, pt1=(150,20), pt2=(60,80), color=(0,255,0),thickness=10)
cv.rectangle(me, pt1=(130,360), pt2=(330,150), color=(255,255,255),thickness=10)
cv.rectangle(me, pt1=(100,900), pt2=(240,230), color=(255,0,0),thickness=10)
cv.rectangle(me, pt1=(230,30), pt2=(50,70), color=(0,0,255),thickness=10)
plt.imshow(me)

# %%
#TUGAS NO 5
#Tampilkan image dengan posisi terbalik!
me2 = cv.flip(cv.cvtColor(me,cv.COLOR_BGR2RGB), 0)
plt.imshow(me2)

# %%
#TUGAS NO 6
#Buat rectangle dan circle pada bagian wajah dari image kitten!
kitten1 = img3
cv.circle(kitten, (340,110), 150, (255,0,0), 5)
plt.imshow(kitten1)

# %%
#TUGAS NO 7
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB 
#dari citra kitten01.jpg!
kitten01 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
cv.rectangle(kitten01,pt1=(100,590),pt2=(10,450),color=(0,255,0),thickness=10)
plt.imshow(kitten01)
